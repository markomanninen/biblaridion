# %%
import biblaridion as bn
# Out:
# Retrieving Strong's data from local csv copy...

# %%
byzantine_2000 = bn.load_dataframe('greek_byzantine_2000_parsed_utf8', 'byzantine_2000')
# Out:
# Retrieving data from local csv copy...

# %%
wh_ubs4_var1 = bn.load_dataframe('greek_WH_UBS4_parsed_utf8', 'wh_ubs4', 'var1')
wh_ubs4_var2 = bn.load_dataframe('greek_WH_UBS4_parsed_utf8', 'wh_ubs4', 'var2')
# Out:
# Retrieving data from local csv copy...
# Retrieving data from local csv copy...

# %%
textus_receptus_var1 = bn.load_dataframe('greek_textus_receptus_utf8', 'textus_receptus', 'var1')
textus_receptus_var2 = bn.load_dataframe('greek_textus_receptus_utf8', 'textus_receptus', 'var2')
# Out:
# Retrieving data from local csv copy...
# Retrieving data from local csv copy...

# %%
tischendorf = bn.load_dataframe('greek_tischendorf_utf8', 'tischendorf')
# Out:
# Retrieving data from local csv copy...

# %%
modern = bn.load_dataframe('greek_modern_utf8', 'modern')
# Out:
# Retrieving data from local csv copy...

# %%
sblgnt = bn.load_dataframe('sblgnt', 'sblgnt')
# Out:
# Retrieving data from local csv copy...

# %%
variations = {}

for k, v in (('byzantine', byzantine_2000),
             ('wh_ubs4_var1', wh_ubs4_var1),
             ('wh_ubs4_var2', wh_ubs4_var2),
             ('tr_var1', textus_receptus_var1),
             ('tr_var2', textus_receptus_var2),
             ('sblgnt', sblgnt),
             ('tischendorf', tischendorf),
             ('modern', modern)):
    variations[k] = {'data': v[v['orig_book_index'] == 'Revelation']}
    variations[k]['text'] = ''.join(variations[k]['data'].text)
    variations[k]['words_count'] = len(variations[k]['text'].split(" "))
    variations[k]['chars_count'] = len(variations[k]['text'].replace(" ", ''))
    
    print ("%s  \t%s\t%s\t%s" % (k, variations[k]['words_count'], variations[k]['chars_count'], variations[k]['chars_count']/1224))
    print ("%s  \t%s\t%s\t%s" % (k, variations[k]['words_count'], variations[k]['chars_count'], variations[k]['chars_count']/1260))
    print ()
# Out:
# byzantine  	9402	45829	37.44199346405229
# byzantine  	9402	45829	36.37222222222222
#
# wh_ubs4_var1  	9354	45657	37.3014705882353
# wh_ubs4_var1  	9354	45657	36.23571428571429
#
# wh_ubs4_var2  	9373	45716	37.349673202614376
# wh_ubs4_var2  	9373	45716	36.282539682539685
#
# tr_var1  	9530	46512	38.0
# tr_var1  	9530	46512	36.91428571428571
#
# tr_var2  	9559	46626	38.09313725490196
# tr_var2  	9559	46626	37.00476190476191
#
# sblgnt  	9429	45960	37.549019607843135
# sblgnt  	9429	45960	36.476190476190474
#
# tischendorf  	9426	45924	37.51960784313726
# tischendorf  	9426	45924	36.44761904761905
#
# modern  	10230	49674	40.583333333333336
# modern  	10230	49674	39.423809523809524

# %%
variations['byzantine']['data']
# Out:
#      orig_book_index  orig_chapter  orig_verse  \
# 7553      Revelation             1           1
# 7554      Revelation             1           2
# 7555      Revelation             1           3
# 7556      Revelation             1           4
# 7557      Revelation             1           5
# 7558      Revelation             1           6
# 7559      Revelation             1           7
# 7560      Revelation             1           8
# 7561      Revelation             1           9
# 7562      Revelation             1          10
# 7563      Revelation             1          11
# 7564      Revelation             1          12
# 7565      Revelation             1          13
# 7566      Revelation             1          14
# 7567      Revelation             1          15
# 7568      Revelation             1          16
# 7569      Revelation             1          17
# 7570      Revelation             1          18
# 7571      Revelation             1          19
# ...

# %%
variations['wh_ubs4_var1']['data']
# Out:
#      orig_book_index  orig_chapter  orig_verse  \
# 7553      Revelation             1           1
# 7554      Revelation             1           2
# 7555      Revelation             1           3
# 7556      Revelation             1           4
# 7557      Revelation             1           5
# 7558      Revelation             1           6
# 7559      Revelation             1           7
# 7560      Revelation             1           8
# 7561      Revelation             1           9
# 7562      Revelation             1          10
# 7563      Revelation             1          11
# 7564      Revelation             1          12
# 7565      Revelation             1          13
# 7566      Revelation             1          14
# 7567      Revelation             1          15
# 7568      Revelation             1          16
# 7569      Revelation             1          17
# 7570      Revelation             1          18
# 7571      Revelation             1          19
# ...

# %%
variations['wh_ubs4_var2']['data']
# Out:
#      orig_book_index  orig_chapter  orig_verse  \
# 7553      Revelation             1           1
# 7554      Revelation             1           2
# 7555      Revelation             1           3
# 7556      Revelation             1           4
# 7557      Revelation             1           5
# 7558      Revelation             1           6
# 7559      Revelation             1           7
# 7560      Revelation             1           8
# 7561      Revelation             1           9
# 7562      Revelation             1          10
# 7563      Revelation             1          11
# 7564      Revelation             1          12
# 7565      Revelation             1          13
# 7566      Revelation             1          14
# 7567      Revelation             1          15
# 7568      Revelation             1          16
# 7569      Revelation             1          17
# 7570      Revelation             1          18
# 7571      Revelation             1          19
# ...

# %%
variations['tr_var1']['data']
# Out:
#      orig_book_index  orig_chapter  orig_verse  \
# 7553      Revelation             1           1
# 7554      Revelation             1           2
# 7555      Revelation             1           3
# 7556      Revelation             1           4
# 7557      Revelation             1           5
# 7558      Revelation             1           6
# 7559      Revelation             1           7
# 7560      Revelation             1           8
# 7561      Revelation             1           9
# 7562      Revelation             1          10
# 7563      Revelation             1          11
# 7564      Revelation             1          12
# 7565      Revelation             1          13
# 7566      Revelation             1          14
# 7567      Revelation             1          15
# 7568      Revelation             1          16
# 7569      Revelation             1          17
# 7570      Revelation             1          18
# 7571      Revelation             1          19
# ...

# %%
variations['tr_var2']['data']
# Out:
#      orig_book_index  orig_chapter  orig_verse  \
# 7553      Revelation             1           1
# 7554      Revelation             1           2
# 7555      Revelation             1           3
# 7556      Revelation             1           4
# 7557      Revelation             1           5
# 7558      Revelation             1           6
# 7559      Revelation             1           7
# 7560      Revelation             1           8
# 7561      Revelation             1           9
# 7562      Revelation             1          10
# 7563      Revelation             1          11
# 7564      Revelation             1          12
# 7565      Revelation             1          13
# 7566      Revelation             1          14
# 7567      Revelation             1          15
# 7568      Revelation             1          16
# 7569      Revelation             1          17
# 7570      Revelation             1          18
# 7571      Revelation             1          19
# ...

# %%
variations['sblgnt']['data']
# Out:
#      orig_book_index  orig_chapter  orig_verse  \
# 7522      Revelation             1           1
# 7523      Revelation             1           2
# 7524      Revelation             1           3
# 7525      Revelation             1           4
# 7526      Revelation             1           5
# 7527      Revelation             1           6
# 7528      Revelation             1           7
# 7529      Revelation             1           8
# 7530      Revelation             1           9
# 7531      Revelation             1          10
# 7532      Revelation             1          11
# 7533      Revelation             1          12
# 7534      Revelation             1          13
# 7535      Revelation             1          14
# 7536      Revelation             1          15
# 7537      Revelation             1          16
# 7538      Revelation             1          17
# 7539      Revelation             1          18
# 7540      Revelation             1          19
# ...

# %%
variations['tischendorf']['data']
# Out:
#      orig_book_index  orig_chapter  orig_verse  \
# 7554      Revelation             1           1
# 7555      Revelation             1           2
# 7556      Revelation             1           3
# 7557      Revelation             1           4
# 7558      Revelation             1           5
# 7559      Revelation             1           6
# 7560      Revelation             1           7
# 7561      Revelation             1           8
# 7562      Revelation             1           9
# 7563      Revelation             1          10
# 7564      Revelation             1          11
# 7565      Revelation             1          12
# 7566      Revelation             1          13
# 7567      Revelation             1          14
# 7568      Revelation             1          15
# 7569      Revelation             1          16
# 7570      Revelation             1          17
# 7571      Revelation             1          18
# 7572      Revelation             1          19
# ...

# %%
variations['modern']['data']
# Out:
#       orig_book_index  orig_chapter  orig_verse  \
# 30698      Revelation             1           1
# 30699      Revelation             1           2
# 30700      Revelation             1           3
# 30701      Revelation             1           4
# 30702      Revelation             1           5
# 30703      Revelation             1           6
# 30704      Revelation             1           7
# 30705      Revelation             1           8
# 30706      Revelation             1           9
# 30707      Revelation             1          10
# 30708      Revelation             1          11
# 30709      Revelation             1          12
# 30710      Revelation             1          13
# 30711      Revelation             1          14
# 30712      Revelation             1          15
# 30713      Revelation             1          16
# 30714      Revelation             1          17
# 30715      Revelation             1          18
# ...

# %%
#''.join([x for x in bn.find(r"^%s$" % "α", 'word').lemma])
# Out:
# ''

# %%
#','.join([x for x in bn.find(r"(?i)^%s$" % "G71", 'lemma').word])
# Out:
# 'αγω'

# %%
#''.join([x for x in bn.find(r"(?i)^%s$" % "φλυαρος", 'word').lemma])
# Out:
# 'G5397'

# %%
from diff import diff_match_patch
from IPython.display import HTML

c = diff_match_patch()

def diff_verses(text1, text2):
    return c.diff_prettyHtml(c.diff_main(text1, text2))

def diff_manuscripts(source = 'tr_var1', target = 'tr_var2'):
    diffs = []
    m = max(variations[source]['data']['orig_chapter'])
    first_chapter = None
    for chapter in range(1, m+1):
        c1 = variations[source]['data'][variations[source]['data']['orig_chapter'] == chapter]
        c2 = variations[target]['data'][variations[target]['data']['orig_chapter'] == chapter]
        for verse in range(1, max(c1.orig_verse)+1):
            v1 = c1[c1.orig_verse == verse]
            v2 = c2[c2.orig_verse == verse]
            t1 = ''.join(v1.text).lower()
            t2 = ''.join(v2.text).lower()
            if t1 != t2:
                if first_chapter is None:
                    first_chapter = chapter
                    first_verse = verse
                diffs.append({'chapter': chapter, 
                              'verse': verse, 
                              'diff': diff_verses(t1, t2), 
                              'isopsephy': (sum(v1.total_isopsephy), sum(v2.total_isopsephy)), 
                              'chars': (len(t1.replace(" ", "")), len(t2.replace(" ", ""))), 
                              'words': (len(t1.split(" ")), len(t2.split(" ")))})
                last_chapter = chapter
                last_verse = verse
    d = "<br/><br/>".join(["<b>%s:%s</b> Words: %d | Chars: %d | Isopsephy: %d - %d = %d<br/><br/>%s" % \
                         (d['chapter'], 
                          d['verse'], 
                          d['words'][1]-d['words'][0], 
                          d['chars'][1]-d['chars'][0], 
                          d['isopsephy'][0],
                          d['isopsephy'][1],
                          d['isopsephy'][1]-d['isopsephy'][0],
                          d['diff']) for d in diffs])
    
    words = sum([d['words'][1]-d['words'][0] for d in diffs])
    chars = sum([d['chars'][1]-d['chars'][0] for d in diffs])
    isopsephy = sum([d['isopsephy'][1]-d['isopsephy'][0] for d in diffs])
    
    return HTML("""<h2>Differences between <b style="background-color: #e6ffe6">%s</b> %s:%s <> <b style="background-color: #ffe6e6">%s</b> %s:%s</h2>
                   <h3>Instances: %d | Words: %d | Chars: %d | Isopsephy: %d</h3><br/><p>%s</p>""" % 
                (source, first_chapter, first_verse, target, last_chapter, last_verse, len(diffs), words, chars, isopsephy, d))

# %%
diff_manuscripts()
# Out:
# <h2>Differences between <b style="background-color: #e6ffe6">tr_var1</b> 1:11 <> <b style="background-color: #ffe6e6">tr_var2</b> 21:20</h2>
# ...

# %%
diff_manuscripts('tr_var1', 'wh_ubs4_var1')
# Out:
# <h2>Differences between <b style="background-color: #e6ffe6">tr_var1</b> 1:2 <> <b style="background-color: #ffe6e6">wh_ubs4_var1</b> 22:21</h2>
# ...

# %%
diff_manuscripts('tr_var2', 'wh_ubs4_var1')
# Out:
# <h2>Differences between <b style="background-color: #e6ffe6">tr_var2</b> 1:2 <> <b style="background-color: #ffe6e6">wh_ubs4_var1</b> 22:21</h2>
# ...

# %%
diff_manuscripts('tr_var1', 'wh_ubs4_var2')
# Out:
# <h2>Differences between <b style="background-color: #e6ffe6">tr_var1</b> 1:2 <> <b style="background-color: #ffe6e6">wh_ubs4_var2</b> 22:21</h2>
# ...

# %%
diff_manuscripts('tr_var2', 'wh_ubs4_var2')
# Out:
# <h2>Differences between <b style="background-color: #e6ffe6">tr_var2</b> 1:2 <> <b style="background-color: #ffe6e6">wh_ubs4_var2</b> 22:21</h2>
# ...

# %%
diff_manuscripts('wh_ubs4_var1', 'wh_ubs4_var2')
# Out:
# <h2>Differences between <b style="background-color: #e6ffe6">wh_ubs4_var1</b> 1:5 <> <b style="background-color: #ffe6e6">wh_ubs4_var2</b> 22:21</h2>
# ...

# %%
diff_manuscripts('tr_var1', 'tischendorf')
# Out:
# <h2>Differences between <b style="background-color: #e6ffe6">tr_var1</b> 1:2 <> <b style="background-color: #ffe6e6">tischendorf</b> 22:21</h2>
# ...

# %%
diff_manuscripts('tr_var2', 'tischendorf')
# Out:
# <h2>Differences between <b style="background-color: #e6ffe6">tr_var2</b> 1:2 <> <b style="background-color: #ffe6e6">tischendorf</b> 22:21</h2>
# ...

# %%
diff_manuscripts('tr_var1', 'sblgnt')
# Out:
# <h2>Differences between <b style="background-color: #e6ffe6">tr_var1</b> 1:2 <> <b style="background-color: #ffe6e6">sblgnt</b> 22:21</h2>
# ...

# %%
diff_manuscripts('tr_var2', 'sblgnt')
# Out:
# <h2>Differences between <b style="background-color: #e6ffe6">tr_var2</b> 1:2 <> <b style="background-color: #ffe6e6">sblgnt</b> 22:21</h2>
# ...

# %%
diff_manuscripts('tr_var1', 'byzantine')
# Out:
# <h2>Differences between <b style="background-color: #e6ffe6">tr_var1</b> 1:2 <> <b style="background-color: #ffe6e6">byzantine</b> 22:21</h2>
# ...

# %%
diff_manuscripts('tr_var2', 'byzantine')
# Out:
# <h2>Differences between <b style="background-color: #e6ffe6">tr_var2</b> 1:2 <> <b style="background-color: #ffe6e6">byzantine</b> 22:21</h2>
# ...

# %%
diff_manuscripts('tischendorf', 'byzantine')
# Out:
# <h2>Differences between <b style="background-color: #e6ffe6">tischendorf</b> 1:2 <> <b style="background-color: #ffe6e6">byzantine</b> 22:21</h2>
# ...

# %%
diff_manuscripts('tischendorf', 'sblgnt')
# Out:
# <h2>Differences between <b style="background-color: #e6ffe6">tischendorf</b> 1:2 <> <b style="background-color: #ffe6e6">sblgnt</b> 22:18</h2>
# ...

# %%
diff_manuscripts('tischendorf', 'wh_ubs4_var1')
# Out:
# <h2>Differences between <b style="background-color: #e6ffe6">tischendorf</b> 1:2 <> <b style="background-color: #ffe6e6">wh_ubs4_var1</b> 22:21</h2>
# ...

# %%
diff_manuscripts('tischendorf', 'wh_ubs4_var2')
# Out:
# <h2>Differences between <b style="background-color: #e6ffe6">tischendorf</b> 1:2 <> <b style="background-color: #ffe6e6">wh_ubs4_var2</b> 22:21</h2>
# ...

# %%
diff_manuscripts('wh_ubs4_var1', 'byzantine')
# Out:
# <h2>Differences between <b style="background-color: #e6ffe6">wh_ubs4_var1</b> 1:4 <> <b style="background-color: #ffe6e6">byzantine</b> 22:21</h2>
# ...

# %%
diff_manuscripts('wh_ubs4_var2', 'byzantine')
# Out:
# <h2>Differences between <b style="background-color: #e6ffe6">wh_ubs4_var2</b> 1:4 <> <b style="background-color: #ffe6e6">byzantine</b> 22:21</h2>
# ...

# %%
diff_manuscripts('wh_ubs4_var1', 'sblgnt')
# Out:
# <h2>Differences between <b style="background-color: #e6ffe6">wh_ubs4_var1</b> 1:5 <> <b style="background-color: #ffe6e6">sblgnt</b> 22:21</h2>
# ...

# %%
diff_manuscripts('wh_ubs4_var2', 'sblgnt')
# Out:
# <h2>Differences between <b style="background-color: #e6ffe6">wh_ubs4_var2</b> 1:6 <> <b style="background-color: #ffe6e6">sblgnt</b> 22:21</h2>
# ...

# %%
diff_manuscripts('sblgnt', 'byzantine')
# Out:
# <h2>Differences between <b style="background-color: #e6ffe6">sblgnt</b> 1:4 <> <b style="background-color: #ffe6e6">byzantine</b> 22:21</h2>
# ...

# %%
46512/9530, 46626/9559, 46626-46512, 144-114, 30/(46626/9559), 216*216, 9559+6, 9559+7
# Out:
# (4.880587618048269,
#  4.8777068731038815,
#  114,
#  30,
#  6.150431089949813,
#  46656,
#  9565,
#  9566)

# %%
import biblaridion.strongs.main as strongs
dctnr = strongs.dictionary
dctnr
# Out:
#       lemma           word                                        translation  \
# 0     G3143     μαρτυρομαι  to be adduced as a witness, i.e. (figuratively...
# 1     G4190        πονηρος  hurtful, i.e. evil (properly, in effect or inf...
# 2     G5234  υπερβαλλοντως                                        excessively
# 3      G260            αμα  properly, at the "same" time, but freely used ...
# 4     G4307        προνοια         forethought, i.e. provident care or supply
# 5     G3161      Ματταθιας  Mattathias (i.e. Mattithjah), an Israelite and...
# 6     G2867         κονιαω                    by analogy, lime); to whitewash
# 7     G1483        εθνικως                                       as a Gentile
# 8      G498   αντιτασσομαι              to range oneself against, i.e. oppose
# 9      G683       απωθομαι               to push off, figuratively, to reject
# 10    G3321    μεσουρανημα                                            mid-sky
# ...

# %%
dctnr['word_length'] = dctnr['word'].map(lambda x: len(x))

# %%
sum(dctnr['word_length'])/len(dctnr['word_length'])
# Out:
# 7.4419699438710847

# %%
dctnr.describe()
# Out:
#          isopsephy  word_length
# count  5523.000000  5523.000000
# mean    963.400869     7.441970
# std     552.051379     2.329058
# min       6.000000     1.000000
# 25%     539.500000     6.000000
# 50%     920.000000     7.000000
# 75%    1315.000000     9.000000
# max    3260.000000    29.000000

# %%
dctnr.groupby(['lemma','word','isopsephy','translation','transliteration','word_length',dctnr.index]).count().reset_index()
# Out:
#       lemma          word  isopsephy  \
# 0        G1            αν         51
# 1       G10        Αβιουδ        487
# 2      G100       αδροτης        683
# 3     G1000          βολη        110
# 4     G1001        βολιζω        919
# 5     G1002         βολις        312
# 6     G1003          Βοοζ        149
# 7     G1004      βορβορος        614
# 8     G1005        βορρας        473
# 9     G1006         βοσκω       1092
# 10    G1007         Βοσορ        442
# 11    G1008        βοτανη        431
# 12    G1009        βοτρυς       1072
# 13     G101      αδυνατεω       1561
# 14    G1010     βουλευτης       1415
# 15    G1011       βουλευω       1707
# 16    G1012         βουλη        510
# 17    G1013       βουλημα        551
# 18    G1014      βουλομαι        623
# 19    G1015        βουνος        792
# 20    G1016          βους        672
# 21    G1017      βραβειον        240
# 22    G1018       βραβευω       1310
# 23    G1019       βραδυνω       1357
# ...
